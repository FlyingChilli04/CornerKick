# %%
# import library to make reqs
import requests

# %%
requests.__version__
# Out:
# '2.31.0'

# %%
# get url we want statistics from
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
# get data
data = requests.get(standings_url)

# %%
# import library for data scraping
from bs4 import BeautifulSoup

# %%
import bs4

# %%
bs4.__version__
# Out:
# '4.12.2'

# %%
# get all html text
soup = BeautifulSoup(data.text)

# %%
# select the table tag using css selector
standings_table = soup.select('table.stats_table')[0]

# %%
# now select a tags -> find all only finds a tags
links = standings_table.find_all('a')

# %%
# go through each a element and finds value of href property
links = [l.get("href") for l in links]

# %%
# just get links with squad in them
links = [l for l in links if '/squads/' in l]

# %%
# use format string to add domain
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
# get first team
team_url = team_urls[0]

# %%
# get its html
data = requests.get(team_url)

# %%
import pandas as pd
import pandas
from io import StringIO
# create panda dataframe
data_string = StringIO(data.text)
matches = pd.read_html(data_string, match="Scores & Fixtures")

# %%
pandas.__version__
# Out:
# '2.1.4'

# %%
matches[0].head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1  2023-08-12  12:30    Premier League          Matchweek 1  Sat     Home
# 2  2023-08-21  20:00    Premier League          Matchweek 2  Mon     Away
# 3  2023-08-26  15:00    Premier League          Matchweek 3  Sat     Home
# 4  2023-09-03  16:30    Premier League          Matchweek 4  Sun     Home
#
#   Result     GF     GA         Opponent   xG  xGA  Poss  Attendance  \
# 0      D  1 (4)  1 (1)  Manchester City  NaN  NaN  45.0     81145.0
# 1      W      2      1  Nott'ham Forest  0.8  1.2  78.0     59984.0
# 2      W      1      0   Crystal Palace  2.0  1.0  53.0     24189.0
# 3      D      2      2           Fulham  3.2  0.6  71.0     59961.0
# 4      W      3      1   Manchester Utd  2.3  0.9  55.0     60192.0
#
#            Captain Formation         Referee  Match Report  \
# ...

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
data_string = StringIO(data.text)
shooting = pd.read_html(data_string, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Arsenal                                                              \
#          Date   Time              Comp                Round  Day    Venue
# 0  2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1  2023-08-12  12:30    Premier League          Matchweek 1  Sat     Home
# 2  2023-08-21  20:00    Premier League          Matchweek 2  Mon     Away
# 3  2023-08-26  15:00    Premier League          Matchweek 3  Sat     Home
# 4  2023-09-03  16:30    Premier League          Matchweek 4  Sun     Home
#
#                                          ... Standard               Expected  \
#   Result     GF     GA         Opponent  ...     Dist   FK PK PKatt       xG
# 0      D  1 (4)  1 (1)  Manchester City  ...      NaN  NaN  0     0      NaN
# 1      W      2      1  Nott'ham Forest  ...     19.1  0.0  0     0      0.8
# 2      W      1      0   Crystal Palace  ...     16.4  0.0  1     1      2.0
# ...

# %%
# get rid of multiple headers
shooting.columns = shooting.columns.droplevel()

# %%
# merge data frames
team_data = matches[0].merge(shooting[["Date", "Sh"]], on="Date")

# %%
team_data
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1   2023-08-12  12:30    Premier League          Matchweek 1  Sat     Home
# 2   2023-08-21  20:00    Premier League          Matchweek 2  Mon     Away
# 3   2023-08-26  15:00    Premier League          Matchweek 3  Sat     Home
# 4   2023-09-03  16:30    Premier League          Matchweek 4  Sun     Home
# 5   2023-09-17  16:30    Premier League          Matchweek 5  Sun     Away
# 6   2023-09-20  20:00      Champions Lg          Group stage  Wed     Home
# 7   2023-09-24  14:00    Premier League          Matchweek 6  Sun     Home
# 8   2023-09-27  19:45           EFL Cup          Third round  Wed     Away
# 9   2023-09-30  15:00    Premier League          Matchweek 7  Sat     Away
# 10  2023-10-03  21:00      Champions Lg          Group stage  Tue     Away
# ...

# %%
years = list(range(2024, 2020, -1))
years
# Out:
# [2024, 2023, 2022, 2021]

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
# get pass types data
links = [l.get("href") for l in soup.find_all('a')]
links = [l for l in links if l and 'all_comps/passing_types/' in l]
data = requests.get(f"https://fbref.com{links[0]}")
passing_type = pd.read_html(StringIO(data.text), match="Pass Types")[0]
passing_type.columns = passing_type.columns.droplevel()

# get posession data
links = [l.get("href") for l in soup.find_all('a')]
links = [l for l in links if l and 'all_comps/possession/' in l]
data = requests.get(f"https://fbref.com{links[0]}")
possession = pd.read_html(StringIO(data.text), match="Possession")[0]
possession.columns = possession.columns.droplevel()

team_data_shooting = matches[0].merge(shooting[["Date", "Sh"]], on="Date")
team_data_passing = team_data_shooting.merge(passing_type[["Date", "CK"]], on="Date")
team_data = team_data_passing.merge(possession[["Date", "Poss", "Touches"]], on="Date")

# %%
team_data_shooting
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1   2023-08-12  12:30    Premier League          Matchweek 1  Sat     Home
# 2   2023-08-21  20:00    Premier League          Matchweek 2  Mon     Away
# 3   2023-08-26  15:00    Premier League          Matchweek 3  Sat     Home
# 4   2023-09-03  16:30    Premier League          Matchweek 4  Sun     Home
# 5   2023-09-17  16:30    Premier League          Matchweek 5  Sun     Away
# 6   2023-09-20  20:00      Champions Lg          Group stage  Wed     Home
# 7   2023-09-24  14:00    Premier League          Matchweek 6  Sun     Home
# 8   2023-09-27  19:45           EFL Cup          Third round  Wed     Away
# 9   2023-09-30  15:00    Premier League          Matchweek 7  Sat     Away
# 10  2023-10-03  21:00      Champions Lg          Group stage  Tue     Away
# ...

# %%
team_data_passing
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1   2023-08-12  12:30    Premier League          Matchweek 1  Sat     Home
# 2   2023-08-21  20:00    Premier League          Matchweek 2  Mon     Away
# 3   2023-08-26  15:00    Premier League          Matchweek 3  Sat     Home
# 4   2023-09-03  16:30    Premier League          Matchweek 4  Sun     Home
# 5   2023-09-17  16:30    Premier League          Matchweek 5  Sun     Away
# 6   2023-09-20  20:00      Champions Lg          Group stage  Wed     Home
# 7   2023-09-24  14:00    Premier League          Matchweek 6  Sun     Home
# 8   2023-09-27  19:45           EFL Cup          Third round  Wed     Away
# 9   2023-09-30  15:00    Premier League          Matchweek 7  Sat     Away
# 10  2023-10-03  21:00      Champions Lg          Group stage  Tue     Away
# ...

# %%
team_data
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1   2023-08-12  12:30    Premier League          Matchweek 1  Sat     Home
# 2   2023-08-21  20:00    Premier League          Matchweek 2  Mon     Away
# 3   2023-08-26  15:00    Premier League          Matchweek 3  Sat     Home
# 4   2023-09-03  16:30    Premier League          Matchweek 4  Sun     Home
# 5   2023-09-17  16:30    Premier League          Matchweek 5  Sun     Away
# 6   2023-09-20  20:00      Champions Lg          Group stage  Wed     Home
# 7   2023-09-24  14:00    Premier League          Matchweek 6  Sun     Home
# 8   2023-09-27  19:45           EFL Cup          Third round  Wed     Away
# 9   2023-09-30  15:00    Premier League          Matchweek 7  Sat     Away
# 10  2023-10-03  21:00      Champions Lg          Group stage  Tue     Away
# ...

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        
        # get scores & fixtures data
        matches = pd.read_html(StringIO(data.text), match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        
        # get shooting data
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(StringIO(data.text), match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        
        # get pass types data
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/passing_types/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        passing_type = pd.read_html(StringIO(data.text), match="Pass Types")[0]
        passing_type.columns = passing_type.columns.droplevel()
        
        # get posession data
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/possession/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        possession = pd.read_html(StringIO(data.text), match="Possession")[0]
        possession.columns = possession.columns.droplevel()
        
        try:
            team_data_shooting = matches.merge(shooting[["Date", "Sh"]], on="Date")
            team_data_passing = team_data_shooting.merge(passing_type[["Date", "CK"]], on="Date")
            team_data = team_data_passing.merge(possession[["Date", "Poss", "Touches"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(15)

# %%
match_df = pd.concat(all_matches)
match_df
# Out:
#           Date   Time            Comp         Round  Day Venue Result GF GA  \
# 1   2023-08-12  12:30  Premier League   Matchweek 1  Sat  Home      W  2  1
# 2   2023-08-21  20:00  Premier League   Matchweek 2  Mon  Away      W  1  0
# 3   2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D  2  2
# 4   2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3  1
# 5   2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1  0
# ..         ...    ...             ...           ...  ...   ...    ... .. ..
# 38  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0  4
# 39  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0  2
# 40  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1  0
# 41  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0  1
# 42  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1  0
#
# ...

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df.to_csv("matches.csv")
